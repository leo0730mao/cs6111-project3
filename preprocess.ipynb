# %%
import pandas as pd

df = pd.read_csv("NYC_Jobs.csv")
df.head()
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0  433216  DEPT OF ENVIRONMENT PROTECTION     External               1
# 1  439131   DEPT OF HEALTH/MENTAL HYGIENE     Internal              12
# 2  302670  DEPT OF ENVIRONMENT PROTECTION     External               1
# 3  436316     TAXI & LIMOUSINE COMMISSION     External               3
# 4  321554  DEPT OF ENVIRONMENT PROTECTION     Internal               1
#
#                                       Business Title  \
# 0  2020-BWS-011-WTO Engineering & Contract Servic...
# 1                        Forensic Quality Specialist
# 2                           Assistant Civil Engineer
# 3                                Radio Room Operator
# 4    Deputy Commissioner, Water and Sewer Operations
#
#               Civil Service Title Title Classification Title Code No Level  \
# 0           SUMMER COLLEGE INTERN    Non-Competitive-5         10234    00
# ...

# %%
colums_to_drop = ["Division/Work Unit", "Work Location 1", "Recruitment Contact", "Post Until", "Hours/Shift", "Job ID", "# Of Positions", "Title Code No", "Additional Information", "Posting Date", "Posting Updated", "Process Date"]
df = df.drop(colums_to_drop, axis = 1)

# %%
df = df.dropna(axis=0, how='any')

# %%
df
# Out:
#                               Agency Posting Type  \
# 0     DEPT OF ENVIRONMENT PROTECTION     External
# 1      DEPT OF HEALTH/MENTAL HYGIENE     Internal
# 2     DEPT OF ENVIRONMENT PROTECTION     External
# 3        TAXI & LIMOUSINE COMMISSION     External
# 4     DEPT OF ENVIRONMENT PROTECTION     Internal
# ...                              ...          ...
# 2078    DEPARTMENT OF BUSINESS SERV.     Internal
# 2079     TAXI & LIMOUSINE COMMISSION     External
# 2080           NYC HOUSING AUTHORITY     External
# 2081   DEPT OF HEALTH/MENTAL HYGIENE     External
# 2082  DEPT OF ENVIRONMENT PROTECTION     External
#
#                                          Business Title  \
# 0     2020-BWS-011-WTO Engineering & Contract Servic...
# 1                           Forensic Quality Specialist
# 2                              Assistant Civil Engineer
# 3                                   Radio Room Operator
# 4       Deputy Commissioner, Water and Sewer Operations
# ...

# %%
df.to_csv("")
